# %%
#exo1
#"A company’s financial reports stored in an Excel file." this is structured data.
#"Photographs uploaded to a social media platform." this is unstructured data.   
#"A collection of news articles on a website."  this is unstructured data.
#"Inventory data in a relational database." this is structured data.
#"Recorded interviews from a market research study." this is unstructured data.

#exo2
#"A series of blog posts about travel experiences." create a database with Attributes like userID|comments|feeling
#"Audio recordings of customer service calls." create a database with Attributes like customerID|audio|comments|services
#"Handwritten notes from a brainstorming session." create a database with Attributes like customerID|note|subject
#"A video tutorial on cooking. create a database" with Attributes like receipieName|qttFlour|qttEgg|nbOfView

#exo3
import pandas as pd
df=pd.read_csv('./train.csv')
print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#exo4
df=pd.read_csv('./Iris_dataset.csv', header=None)
print(df.head())
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
# !pip install openpyxl

# %%
import pandas as pd
frameData = pd.DataFrame({
       'Column1': [1, 2, 3, 4, 5],
       'Column2': ['A', 'B', 'C', 'D', 'E'],
       'Column3': [True, False, True, False, True]
   })
frameData.to_json('frameData.json')
frameData.to_excel('frameData.xlsx', sheet_name='Sheet1')

# %%
#exo6
df=pd.read_json('posts.json')
print(df.head())
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...
